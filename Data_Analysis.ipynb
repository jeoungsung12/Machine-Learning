# %%
import pandas as pd

url = "https://raw.githubusercontent.com/rasbt/python-machine-learning-book-3rd-edition/master/ch10/housing.data.txt"
df = pd.read_csv(filepath_or_buffer=url, header=None, sep="\s+")

df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
chosen = ['AGE', 'DIS', 'TAX']
df[chosen].head()
# Out:
#     AGE     DIS    TAX
# 0  65.2  4.0900  296.0
# 1  78.9  4.9671  242.0
# 2  61.1  4.9671  242.0
# 3  45.8  6.0622  222.0
# 4  54.2  6.0622  222.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cols = ['LSTAT', 'INDUS', 'NOX', 'RM', 'MEDV']
sns.histplot(data=df, x='LSTAT') 
plt.show()

# %%
sns.scatterplot(data=df, x="LSTAT", y="INDUS")
plt.show()

# %%
sns.pairplot(data=df, x_vars=cols, y_vars=cols)
plt.tight_layout() 
plt.show()

# %%
correlation_matrix = df.corr().round(2)

plt.figure(figsize=(20,10))

sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols = ['LSTAT', 'INDUS', 'NOX', 'RM', 'MEDV']
# Histogram to see the distribution of the data in column PTRATIO
sns.histplot(data=df, x='PTRATIO', color = 'r') 
plt.show()

# %%
# Scatter plot to see relationship between 2 variables
sns.scatterplot(data=df, x="LSTAT", y="INDUS", marker='+')
#marker is "+"
plt.show()

# %%
chosen_cols = ['LSTAT', 'INDUS', 'NOX', 'RM', 'MEDV']
df[chosen_cols].head()
df[chosen_cols].info()
print(df[chosen_cols].describe())
df[chosen_cols].describe(include = 'all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   LSTAT   506 non-null    float64
#  1   INDUS   506 non-null    float64
#  2   NOX     506 non-null    float64
#  3   RM      506 non-null    float64
#  4   MEDV    506 non-null    float64
# dtypes: float64(5)
# memory usage: 19.9 KB
#             LSTAT       INDUS         NOX          RM        MEDV
# count  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    12.653063   11.136779    0.554695    6.284634   22.532806
# std      7.141062    6.860353    0.115878    0.702617    9.197104
# min      1.730000    0.460000    0.385000    3.561000    5.000000
# 25%      6.950000    5.190000    0.449000    5.885500   17.025000
# 50%     11.360000    9.690000    0.538000    6.208500   21.200000
# 75%     16.955000   18.100000    0.624000    6.623500   25.000000
# ...
